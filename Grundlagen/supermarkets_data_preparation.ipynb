# %% [markdown]
# # Importing and preparing supermarkets data

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import fnmatch
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Get current working directory
print('Current working directory:', os.getcwd())

# Show .json files in the current working directory
flist = fnmatch.filter(os.listdir('.'), '*.json')
for i in flist:
    print(i)
# Out:
# Current working directory: /workspaces/remo-caprice-project/Grundlagen
# supermarkets.json

# %% [markdown]
# ## Importing data

# %%
# Read the data to a pandas data frame
df1 = pd.read_json('./supermarkets.json', encoding='utf-8')
df1.head(5)
# Out:
#    type        id        lat       lon  \
# 0  node  33126515  47.155616  9.037915
# 1  node  36726161  47.226191  8.980329
# 2  node  39768209  47.225154  8.969868
# 3  node  39947904  47.376732  8.542161
# 4  node  48932835  47.375020  8.522895
#
#                                                 tags
# 0  {'addr:city': 'Schänis', 'addr:country': 'CH',...
# 1  {'addr:city': 'Uznach', 'addr:housenumber': '2...
# 2  {'addr:city': 'Uznach', 'addr:postcode': '8730...
# 3  {'addr:city': 'Zürich', 'addr:country': 'CH', ...
# 4  {'addr:city': 'Zürich', 'addr:housenumber': '7...

# %% [markdown]
# ## Count number of rows and columns in the data frame

# %%
# Dimension (rows, columns)
print('Dimension:', df1.shape)

# Number of rows
print('Number of rows:', df1.shape[0])

# Number of columns
print('Number of columns:', df1.shape[1])
# Out:
# Dimension: (3469, 5)
# Number of rows: 3469
# Number of columns: 5

# %% [markdown]
# ## Column 'tags' is a pandas Series with dictionaries -> change to data frame

# %%
# Type of the first item of column tags
print(type(df1.tags))
print(type(df1.tags[0]))

# Content of the first item of column tags
print(df1.tags[0].keys())

# Change to data frame
df2 = pd.DataFrame.from_records(df1.tags)
df2 = df2[['brand', 'shop', 'addr:city', 'addr:street', 'addr:housenumber', 'addr:postcode', 'opening_hours']]

# Rename selected columns
df2 = df2.rename(columns={'addr:city': 'city',
                          'addr:street':'street',
                          'addr:housenumber': 'housenumber',
                          'addr:postcode': 'postcode',
                          'opening_hours': 'opening_hours'})

# Show first records of data frame
df2.head()
# Out:
# <class 'pandas.core.series.Series'>
# <class 'dict'>
# dict_keys(['addr:city', 'addr:country', 'addr:housenumber', 'addr:postcode', 'addr:street', 'brand', 'brand:wikidata', 'brand:wikipedia', 'check_date:currency:XBT', 'currency:XBT', 'email', 'name', 'opening_hours', 'payment:lightning', 'payment:lightning_contactless', 'payment:onchain', 'phone', 'shop', 'website'])
#     brand         shop     city          street housenumber postcode  \
# 0    Spar  supermarket  Schänis  Biltnerstrasse          32     8718
# 1  Migros  supermarket   Uznach  Zürcherstrasse          25     8730
# 2    Coop  supermarket   Uznach             NaN         NaN     8730
# 3    Coop  supermarket   Zürich   Bahnhofbrücke           1     8001
# 4  Migros  supermarket   Zürich    Wengistrasse           7     8004
#
#                                        opening_hours
# 0  Mo-Th 07:30-19:00; Fr 07:30-20:00; Sa 07:30-17:00
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...
# 2                                                NaN
# 3                                  Mo-Sa 06:00-22:00
# 4                          Mo-Sa 08:00-21:00; PH off

# %% [markdown]
# ## Merge df1 and df2

# %%
# Merge df and df2
df = pd.merge(df1[['type', 'id', 'lat', 'lon']], 
              df2[['brand', 'shop', 'city', 'street', 'housenumber', 'postcode', 'opening_hours']],
              left_index=True, 
              right_index=True)
df.head(5)
# Out:
#    type        id        lat       lon   brand         shop     city  \
# 0  node  33126515  47.155616  9.037915    Spar  supermarket  Schänis
# 1  node  36726161  47.226191  8.980329  Migros  supermarket   Uznach
# 2  node  39768209  47.225154  8.969868    Coop  supermarket   Uznach
# 3  node  39947904  47.376732  8.542161    Coop  supermarket   Zürich
# 4  node  48932835  47.375020  8.522895  Migros  supermarket   Zürich
#
#            street housenumber postcode  \
# 0  Biltnerstrasse          32     8718
# 1  Zürcherstrasse          25     8730
# 2             NaN         NaN     8730
# 3   Bahnhofbrücke           1     8001
# 4    Wengistrasse           7     8004
#
#                                        opening_hours
# 0  Mo-Th 07:30-19:00; Fr 07:30-20:00; Sa 07:30-17:00
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...
# 2                                                NaN
# 3                                  Mo-Sa 06:00-22:00
# 4                          Mo-Sa 08:00-21:00; PH off

# %% [markdown]
# ## Count and identify the number of missing values (if any)

# %%
# Count missing values
print(pd.isna(df).sum())

# Identify rows with missing values, e.g.:
df.loc[pd.isna(df['city'])]
# Out:
# type                0
# id                  0
# lat                 0
# lon                 0
# brand             756
# shop                0
# city             1691
# street           1544
# housenumber      1601
# postcode         1623
# opening_hours     872
# dtype: int64
#       type           id        lat       lon      brand         shop city  \
# 5     node     70656485  47.491253  8.733981        NaN  supermarket  NaN
# 9     node     81321513  47.532917  9.066408      Landi  supermarket  NaN
# 14    node    112148390  47.448772  8.215075        NaN  supermarket  NaN
# 16    node    121994447  47.545863  7.583605        Pam  supermarket  NaN
# 20    node    128269749  47.381684  8.238918        NaN  supermarket  NaN
# ...    ...          ...        ...       ...        ...          ...  ...
# 3461  node  13275370001  46.995038  6.943915        NaN  supermarket  NaN
# 3462  node  13285536907  46.213355  6.129913  MM Migros  supermarket  NaN
# 3464  node  13302166763  47.369876  8.508189     Müller  supermarket  NaN
# 3465  node  13302401281  47.203519  8.758658        NaN  supermarket  NaN
# 3466  node  13310499701  46.983653  6.904294        NaN  supermarket  NaN
#
#      street housenumber postcode                   opening_hours
# 5       NaN         NaN      NaN                             NaN
# 9       NaN         NaN      NaN  Mo-Sa 08:00-12:00, 13:30-18:00
# 14      NaN         NaN      NaN                             NaN
# 16      NaN         NaN      NaN                             NaN
# 20      NaN         NaN      NaN                             NaN
# ...     ...         ...      ...                             ...
# 3461    NaN         NaN      NaN                             NaN
# 3462    NaN         NaN      NaN                             NaN
# 3464    NaN         NaN      NaN                             NaN
# 3465    NaN         NaN      NaN               Mo-Sa 07:00-20:00
# 3466    NaN         NaN      NaN                             NaN
#
# [1691 rows x 11 columns]

# %% [markdown]
# ## Count and identify duplicated values (if any)

# %%
# Count duplicated values
print(df.duplicated().sum())

# Identify rows with duplicated values, e.g.:
df[df[['id']].duplicated()]
# Out:
# 0
# Empty DataFrame
# Columns: [type, id, lat, lon, brand, shop, city, street, housenumber, postcode, opening_hours]
# Index: []

# %% [markdown]
# ## Get data types of all variables

# %%
# Get data types (note that in pandas, a string is referred to as 'object')
df.dtypes
# Out:
# type              object
# id                 int64
# lat              float64
# lon              float64
# brand             object
# shop              object
# city              object
# street            object
# housenumber       object
# postcode          object
# opening_hours     object
# dtype: object

# %% [markdown]
# ## Filter the supermarkets

# %%
# additional filters on supermarkets
df_filtered_1= df.loc[(df['brand'] == 'Migros') & (df['city'] =='Zürich')]
df_filtered_2 = df.loc[(df['brand'] == 'Coop') & (df['city'].isin(['Zürich', 'Bern', 'Basel']))]

df_filtered_1.head()
df_filtered_2.head()
# Out:
#     type         id        lat       lon brand         shop    city  \
# 3   node   39947904  47.376732  8.542161  Coop  supermarket  Zürich
# 8   node   79977755  47.340070  8.530546  Coop  supermarket  Zürich
# 58  node  265776668  47.376417  8.559594  Coop  supermarket  Zürich
# 62  node  266630559  47.377716  8.511219  Coop  supermarket  Zürich
# 70  node  267468996  47.364872  8.521006  Coop  supermarket  Zürich
#
#                    street housenumber postcode  \
# 3           Bahnhofbrücke           1     8001
# 8   Alte Kalchbühlstrasse          15     8038
# 58      Zürichbergstrasse          75     8044
# 62         Badenerstrasse         333     8003
# 70       Uetlibergstrasse          20     8045
#
#                         opening_hours
# 3                   Mo-Sa 06:00-22:00
# 8           Mo-Sa 07:30-21:00; PH off
# 58  Mo-Fr 07:00-21:00; Sa 07:30-20:00
# 62          Mo-Sa 07:00-22:00; PH off
# 70                  Mo-Sa 07:30-21:00

# %% [markdown]
# ## Count all Coop supermarkets in Zurich, Bern & Basel

# %%
# Filter all Coop supermarkets in Zurich, Bern & Basel
df_coop = df.loc[(df['brand'] == 'Coop') & (df['city'].isin(['Zürich', 'Bern', 'Basel']))]
print('Number of Coop supermarkets in Zurich, Bern & Basel:', df_coop.shape[0])
# Out:
# Number of Coop supermarkets in Zurich, Bern & Basel: 64

# %% [markdown]
# ## Filter Supermarkets with availabel brand, city, house number, postcode and opening hours

# %%
# Filter Supermarkets with availabel brand, city, house number, postcode and opening hours 
df_cleaned = df.dropna(subset=['brand', 'city', 'housenumber', 'postcode', 'opening_hours'])
print('Dimension of cleaned data frame:', df_cleaned.shape)
# Out:
# Dimension of cleaned data frame: (1195, 11)

# %% [markdown]
# ## Count all supermarkets with all available data

# %%
# Count all supermarkets with all available data
print('Number of supermarkets with all available data:', df_cleaned.shape[0])
# Out:
# Number of supermarkets with all available data: 1195

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('./supermarkets_data_filtered.csv', 
          sep=",", 
          encoding='utf-8',
          index=False)

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-11-28 10:00:56
# Python Version: 3.11.14
# -----------------------------------
